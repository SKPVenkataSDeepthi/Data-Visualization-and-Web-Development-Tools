# %% [markdown]
# A Box Plot is also known as a Whisker Plot and is a standardized way of displaying the distribution of data based on a five-number summary: minimum, first quartile (Q1), median (Q2), third quartile (Q3) and maximum. It can also show outliers

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the custom dataset 
df = pd.read_csv('Airline Dataset Updated - v2.csv')

df.head()

# Extract the Age column for the box plot
ages = df['Age'].values

# Create a box plot
plt.boxplot(ages, vert=True, patch_artist=True, 
            boxprops=dict(facecolor='skyblue'),
            medianprops=dict(color='red'))

plt.xlabel('Age')
plt.ylabel('Values')
plt.title('Box Plot of Age')
plt.show()

# %%
# 2. Horizontal Box Plot
plt.boxplot(df['Age'], vert=False, patch_artist=True, 
            boxprops=dict(facecolor='lightgreen'),
            medianprops=dict(color='purple'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15532d790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15532dca0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x15532d4f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15532e270>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15532e4e0>],
#  'means': []}

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
df.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
# 3. Customizing whiskers and fillers
plt.boxplot(df['Age'], vert=True, patch_artist=True, 
            whiskerprops=dict(color='orange', linewidth=2),
            flierprops=dict(marker='o', color='purple', markersize=8),
            boxprops=dict(facecolor='lightblue'),
            medianprops=dict(color='red'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1552b5820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1552b6d50>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1552b6210>],
#  'medians': [<matplotlib.lines.Line2D at 0x1552b55b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x136989670>],
#  'means': []}

# %%
# 4. Adding notches --- represent the confidence interval around the median
plt.boxplot(df['Age'], vert=True, patch_artist=True, notch=True,
            boxprops=dict(facecolor='lightyellow'),
            medianprops=dict(color='black'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1552b7860>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15539bbf0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x15539b3e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1553c4170>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1553c4470>],
#  'means': []}

# %%
# 5. changing box plot width
plt.boxplot(df['Age'], vert=True, patch_artist=True, widths=0.5, 
            boxprops=dict(facecolor='lightblue'),
            medianprops=dict(color='red'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x155415160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1554156a0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1553f0e90>],
#  'medians': [<matplotlib.lines.Line2D at 0x155415b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x155415e50>],
#  'means': []}

# %%
# 6. Adding grid
plt.boxplot(df['Age'], vert=True, patch_artist=True, 
            boxprops=dict(facecolor='lightblue'),
            medianprops=dict(color='red'))
plt.grid(True)

# %%
import numpy as np
# Adding Data Points (Overlaying Scatter Plot)
plt.boxplot(df['Age'], vert=True, patch_artist=True, 
            boxprops=dict(facecolor='lightblue'),
            medianprops=dict(color='red'))
plt.scatter(np.random.normal(1, 0.04, size=len(df['Age'])), df['Age'], alpha=0.5, color='black')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder


# Convert 'Nationality' to numeric 
label_encoder = LabelEncoder()
df['Nationality'] = label_encoder.fit_transform(df['Nationality'])

# Plotting multiple columns
plt.boxplot([df['Age'], df['Nationality']], vert=True, patch_artist=True, 
            boxprops=dict(facecolor='lightblue'),
            medianprops=dict(color='red'))

# Customizing the x-axis ticks and labels
plt.xticks([1, 2], ['Age', 'Nationality'])  # Adjusting the tick labels
plt.xlabel('Attributes')
plt.ylabel('Values')
plt.title('Box Plot of Age and Nationality')
plt.show()
